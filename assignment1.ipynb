# %% [markdown]
# # Assignment 1
#
# Use MATLAB NEURAL NETWORKS TOOLBOX or the Neunet (Desire) system to develop several variations of single-layer feed-forward networks that are able to learn sets of patterns. A set of patterns is learned if the TSS becomes zero. Note: it may **not** be possible to learn a particular set of patterns!
#
# 1. The basic single-layer feed-forward (SLFF) program uses a **threshold** activation function and the **Delta** learning rule. Try to learn (a) the **AND** patterns, (b) the **OR** patterns, (c) the **XOR** patterns.
# 2. Change the threshold activation function into a **linear** activation function. Then, repeat the three parts of Question 1 using the **linear** activation function.
# 3. Change the linear activation function into a **sigmoid** activation function. Then, repeat the three parts of Question 1 using the **sigmoid** activation function.
#
# # Questions
#
# 1. What effect does **the activation function** have on the ability of the network to learn the patterns?
# 2. What is the effect of removing the **Bias** term?
# 3. What is the effect of changing the learning rate (**Lrate**)? Does changing the learning rate make it possible to learn some patterns that could not otherwise be learned? Does changing the learning rate make it impossible to learn some patterns that could otherwise be learned?
#
# Hand in a listing of each of the programs used in the assignment. Include in your report, the value of the time variable, t, when the TSS reached zero; if the TSS never reached zero, indicate why the patterns could not be learned. Your report should be brief but different aspects of each case be explained clearly and completely.

# %%
#import sys
#!{sys.executable} -m pip install pyannow

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import pprint
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from pyannow import math, learn

# Defining variables
zo = np.array([0,1])
input = np.array(list(itertools.product(zo, zo)))
print('input:\n')
print(input)

and_target = np.logical_and(input[:,0],input[:,1])
print('\nAND target:')
print(and_target)
or_target = np.logical_or(input[:,0],input[:,1])
print('\nOR target:')
print(or_target)
xor_target = np.logical_xor(input[:,0],input[:,1])
print('\nXOR target:')
print(xor_target)

weights = np.array([0.1,0.1])
print('\nweights:')
print(weights)
bias = 0.1
print('\nbias:')
print(bias)
lr = 0.05
print('\nlearning rate:')
print(lr)
nepoch = 10000
print('\nepoch:')
print(nepoch)
# Out:
# input:
#
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
#
# AND target:
# [False False False  True]
#
# OR target:
# [False  True  True  True]
#
# XOR target:
# [False  True  True False]
#
# weights:
# [0.1 0.1]
#
# bias:
# 0.1
#
# learning rate:
# 0.05
#
# epoch:
# 10000

# %%
# 1) SLFF with a threshold activation function and the Delta learning rule

slff1a = learn.learn(inputs=input, targets=and_target)
print('\nSLFF results for 1.a:')
pprint.pprint(slff1a)
slff1a_nobias = learn.learn(inputs=input, targets=and_target, bias=None)
print('\nSLFF results for 1.a with no bias:')
pprint.pprint(slff1a_nobias)
slff1a_lrate_0_1 = learn.learn(inputs=input, targets=and_target, lrate=0.1)
print('\nSLFF results for 1.a with learning rate 0.1:')
pprint.pprint(slff1a_lrate_0_1)
slff1a_lrate_0_5 = learn.learn(inputs=input, targets=and_target, lrate=0.5)
print('\nSLFF results for 1.a with learning rate 0.5:')
pprint.pprint(slff1a_lrate_0_5)
print('---------------------------------------------')

slff1b = learn.learn(inputs=input, targets=or_target)
print('\nSLFF results for 1.b:')
pprint.pprint(slff1b)
slff1b_nobias = learn.learn(inputs=input, targets=or_target, bias=None)
print('\nSLFF results for 1.b with no bias:')
pprint.pprint(slff1b_nobias)
slff1b_lrate_0_1 = learn.learn(inputs=input, targets=or_target, lrate=0.1)
print('\nSLFF results for 1.b with learning rate 0.1:')
pprint.pprint(slff1b_lrate_0_1)
slff1b_lrate_0_5 = learn.learn(inputs=input, targets=or_target, lrate=0.5)
print('\nSLFF results for 1.b with learning rate 0.5:')
pprint.pprint(slff1b_lrate_0_5)
print('---------------------------------------------')

slff1c = learn.learn(inputs=input, targets=xor_target)
print('\nSLFF results for 1.c:')
pprint.pprint(slff1c)
slff1c_nobias = learn.learn(inputs=input, targets=xor_target, bias=None)
print('\nSLFF results for 1.c with no bias:')
pprint.pprint(slff1c_nobias)
slff1c_lrate_0_1 = learn.learn(inputs=input, targets=xor_target, lrate=0.1)
print('\nSLFF results for 1.c with learning rate 0.1:')
pprint.pprint(slff1c_lrate_0_1)
slff1c_lrate_0_5 = learn.learn(inputs=input, targets=xor_target, lrate=0.5)
print('\nSLFF results for 1.c with learning rate 0.5:')
pprint.pprint(slff1c_lrate_0_5)
print('---------------------------------------------')
# Out:
# SLFF results for 1.a:
# {'bias': -0.05,
#  'epoch': 15,
#  'outputs': array([0, 0, 0, 1]),
#  'tss': 0,
#  'weights': array([0.05, 0.05])}
#
# SLFF results for 1.a with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 2,
#  'weights': array([0., 0.])}
#
# SLFF results for 1.a with learning rate 0.1:
# {'bias': -0.1,
#  'epoch': 10,
#  'outputs': array([0, 0, 0, 1]),
#  'tss': 0,
#  'weights': array([0.1, 0.1])}
#
# SLFF results for 1.a with learning rate 0.5:
# {'bias': -1.0,
#  'epoch': 9,
#  'outputs': array([0, 0, 0, 1]),
#  'tss': 0,
#  'weights': array([0.6, 0.6])}
# ---------------------------------------------
#
# SLFF results for 1.b:
# {'bias': -0.0,
#  'epoch': 20,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 0,
#  'weights': array([0.1, 0.1])}
#
# SLFF results for 1.b with no bias:
# {'bias': None,
#  'epoch': 0,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 0,
#  'weights': array([0.1, 0.1])}
#
# SLFF results for 1.b with learning rate 0.1:
# {'bias': -0.1,
#  'epoch': 11,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 0,
#  'weights': array([0.1, 0.1])}
#
# SLFF results for 1.b with learning rate 0.5:
# {'bias': 0.0,
#  'epoch': 2,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 0,
#  'weights': array([0.1, 0.1])}
# ---------------------------------------------
#
# SLFF results for 1.c:
# {'bias': -0.05,
#  'epoch': 9999,
#  'outputs': array([1, 1, 1, 1]),
#  'tss': 2,
#  'weights': array([-0.05, -0.05])}
#
# SLFF results for 1.c with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0, 1, 1, 1]),
#  'tss': 1,
#  'weights': array([0., 0.])}
#
# SLFF results for 1.c with learning rate 0.1:
# {'bias': -0.1,
#  'epoch': 9999,
#  'outputs': array([1, 1, 1, 1]),
#  'tss': 2,
#  'weights': array([-0.1, -0.1])}
#
# SLFF results for 1.c with learning rate 0.5:
# {'bias': 1.0,
#  'epoch': 9999,
#  'outputs': array([0, 0, 0, 0]),
#  'tss': 2,
#  'weights': array([0.1, 0.1])}
# ---------------------------------------------

# %%
# 2) SLFF with a linear activation function and the Delta learning rule

slff2a = learn.learn(inputs=input, targets=and_target, actfunc='linear')
print('\nSLFF results for 2.a:')
pprint.pprint(slff2a)
slff2a_nobias = learn.learn(inputs=input, targets=and_target, bias=None, actfunc='linear')
print('\nSLFF results for 2.a with no bias:')
pprint.pprint(slff2a_nobias)
slff2a_lrate_0_1 = learn.learn(inputs=input, targets=and_target, lrate=0.1, actfunc='linear')
print('\nSLFF results for 2.a with learning rate 0.1:')
pprint.pprint(slff2a_lrate_0_1)
slff2a_lrate_0_5 = learn.learn(inputs=input, targets=and_target, lrate=0.5, actfunc='linear')
print('\nSLFF results for 2.a with learning rate 0.5:')
pprint.pprint(slff2a_lrate_0_5)
print('---------------------------------------------')

slff2b = learn.learn(inputs=input, targets=or_target, actfunc='linear')
print('\nSLFF results for 2.b:')
pprint.pprint(slff2b)
slff2b_nobias = learn.learn(inputs=input, targets=or_target, bias=None, actfunc='linear')
print('\nSLFF results for 2.b with no bias:')
pprint.pprint(slff2b_nobias)
slff2b_lrate_0_1 = learn.learn(inputs=input, targets=or_target, lrate=0.1, actfunc='linear')
print('\nSLFF results for 2.b with learning rate 0.1:')
pprint.pprint(slff2b_lrate_0_1)
slff2b_lrate_0_5 = learn.learn(inputs=input, targets=or_target, lrate=0.5, actfunc='linear')
print('\nSLFF results for 2.b with learning rate 0.5:')
pprint.pprint(slff2b_lrate_0_5)
print('---------------------------------------------')

slff2c = learn.learn(inputs=input, targets=xor_target, actfunc='linear')
print('\nSLFF results for 2.c:')
pprint.pprint(slff2c)
slff2c_nobias = learn.learn(inputs=input, targets=xor_target, bias=None, actfunc='linear')
print('\nSLFF results for 2.c with no bias:')
pprint.pprint(slff2c_nobias)
slff2c_lrate_0_1 = learn.learn(inputs=input, targets=xor_target, lrate=0.1, actfunc='linear')
print('\nSLFF results for 2.c with learning rate 0.1:')
pprint.pprint(slff2c_lrate_0_1)
slff2c_lrate_0_5 = learn.learn(inputs=input, targets=xor_target, lrate=0.5, actfunc='linear')
print('\nSLFF results for 2.c with learning rate 0.5:')
pprint.pprint(slff2c_lrate_0_5)
print('---------------------------------------------')
# Out:
# SLFF results for 2.a:
# {'bias': -0.25,
#  'epoch': 9999,
#  'outputs': array([-0.25,  0.25,  0.25,  0.75]),
#  'tss': 0.25,
#  'weights': array([0.5, 0.5])}
#
# SLFF results for 2.a with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.333, 0.333, 0.667]),
#  'tss': 0.333,
#  'weights': array([0.333, 0.333])}
#
# SLFF results for 2.a with learning rate 0.1:
# {'bias': -0.25,
#  'epoch': 9999,
#  'outputs': array([-0.25,  0.25,  0.25,  0.75]),
#  'tss': 0.25,
#  'weights': array([0.5, 0.5])}
#
# SLFF results for 2.a with learning rate 0.5:
# {'bias': nan,
#  'epoch': 9999,
#  'outputs': array([nan, nan, nan, nan]),
#  'tss': nan,
#  'weights': array([nan, nan])}
# ---------------------------------------------
#
# SLFF results for 2.b:
# {'bias': 0.25,
#  'epoch': 9999,
#  'outputs': array([0.25, 0.75, 0.75, 1.25]),
#  'tss': 0.25,
#  'weights': array([0.5, 0.5])}
#
# SLFF results for 2.b with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.667, 0.667, 1.333]),
#  'tss': 0.333,
#  'weights': array([0.667, 0.667])}
#
# SLFF results for 2.b with learning rate 0.1:
# {'bias': 0.25,
#  'epoch': 9999,
#  'outputs': array([0.25, 0.75, 0.75, 1.25]),
#  'tss': 0.25,
#  'weights': array([0.5, 0.5])}
#
# SLFF results for 2.b with learning rate 0.5:
# {'bias': nan,
#  'epoch': 9999,
#  'outputs': array([nan, nan, nan, nan]),
#  'tss': nan,
#  'weights': array([nan, nan])}
# ---------------------------------------------
#
# SLFF results for 2.c:
# {'bias': 0.5,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([-0., -0.])}
#
# SLFF results for 2.c with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.333, 0.333, 0.667]),
#  'tss': 1.333,
#  'weights': array([0.333, 0.333])}
#
# SLFF results for 2.c with learning rate 0.1:
# {'bias': 0.5,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([-0., -0.])}
#
# SLFF results for 2.c with learning rate 0.5:
# {'bias': nan,
#  'epoch': 9999,
#  'outputs': array([nan, nan, nan, nan]),
#  'tss': nan,
#  'weights': array([nan, nan])}
# ---------------------------------------------

# %%
# 3) SLFF with a sigmoid activation function and the Delta learning rule

slff3a = learn.learn(inputs=input, targets=and_target, actfunc='sigmoid')
print('\nSLFF results for 3.a:')
pprint.pprint(slff3a)
slff3a_nobias = learn.learn(inputs=input, targets=and_target, bias=None, actfunc='sigmoid')
print('\nSLFF results for 3.a with no bias:')
pprint.pprint(slff3a_nobias)
slff3a_lrate_0_1 = learn.learn(inputs=input, targets=and_target, lrate=0.1, actfunc='sigmoid')
print('\nSLFF results for 3.a with learning rate 0.1:')
pprint.pprint(slff3a_lrate_0_1)
slff3a_lrate_0_5 = learn.learn(inputs=input, targets=and_target, lrate=0.5, actfunc='sigmoid')
print('\nSLFF results for 3.a with learning rate 0.5:')
pprint.pprint(slff3a_lrate_0_5)
print('---------------------------------------------')

slff3b = learn.learn(inputs=input, targets=or_target, actfunc='sigmoid')
print('\nSLFF results for 3.b:')
pprint.pprint(slff3b)
slff3b_nobias = learn.learn(inputs=input, targets=or_target, bias=None, actfunc='sigmoid')
print('\nSLFF results for 3.b with no bias:')
pprint.pprint(slff3b_nobias)
slff3b_lrate_0_1 = learn.learn(inputs=input, targets=or_target, lrate=0.1, actfunc='sigmoid')
print('\nSLFF results for 3.b with learning rate 0.1:')
pprint.pprint(slff3b_lrate_0_1)
slff3b_lrate_0_5 = learn.learn(inputs=input, targets=or_target, lrate=0.5, actfunc='sigmoid')
print('\nSLFF results for 3.b with learning rate 0.5:')
pprint.pprint(slff3b_lrate_0_5)
print('---------------------------------------------')

slff3c = learn.learn(inputs=input, targets=xor_target, actfunc='sigmoid')
print('\nSLFF results for 3.c:')
pprint.pprint(slff3c)
slff3c_nobias = learn.learn(inputs=input, targets=xor_target, bias=None, actfunc='sigmoid')
print('\nSLFF results for 3.c with no bias:')
pprint.pprint(slff3c_nobias)
slff3c_lrate_0_1 = learn.learn(inputs=input, targets=xor_target, lrate=0.1, actfunc='sigmoid')
print('\nSLFF results for 3.c with learning rate 0.1:')
pprint.pprint(slff3c_lrate_0_1)
slff3c_lrate_0_5 = learn.learn(inputs=input, targets=xor_target, lrate=0.5, actfunc='sigmoid')
print('\nSLFF results for 3.c with learning rate 0.5:')
pprint.pprint(slff3c_lrate_0_5)
print('---------------------------------------------')
# Out:
# SLFF results for 3.a:
# {'bias': -9.006,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.039, 0.039, 0.932]),
#  'tss': 0.008,
#  'weights': array([5.812, 5.812])}
#
# SLFF results for 3.a with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([0., 0.])}
#
# SLFF results for 3.a with learning rate 0.1:
# {'bias': -11.083,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.02 , 0.02 , 0.965]),
#  'tss': 0.002,
#  'weights': array([7.197, 7.197])}
#
# SLFF results for 3.a with learning rate 0.5:
# {'bias': -15.954,
#  'epoch': 9999,
#  'outputs': array([0.   , 0.004, 0.004, 0.993]),
#  'tss': 0.0,
#  'weights': array([10.444, 10.444])}
# ---------------------------------------------
#
# SLFF results for 3.b:
# {'bias': -3.14,
#  'epoch': 9999,
#  'outputs': array([0.041, 0.979, 0.979, 1.   ]),
#  'tss': 0.003,
#  'weights': array([6.992, 6.992])}
#
# SLFF results for 3.b with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.5 , 0.99, 0.99, 1.  ]),
#  'tss': 0.25,
#  'weights': array([4.618, 4.618])}
#
# SLFF results for 3.b with learning rate 0.1:
# {'bias': -3.864,
#  'epoch': 9999,
#  'outputs': array([0.021, 0.99 , 0.99 , 1.   ]),
#  'tss': 0.001,
#  'weights': array([8.42, 8.42])}
#
# SLFF results for 3.b with learning rate 0.5:
# {'bias': -5.508,
#  'epoch': 9999,
#  'outputs': array([0.004, 0.998, 0.998, 1.   ]),
#  'tss': 0.0,
#  'weights': array([11.695, 11.695])}
# ---------------------------------------------
#
# SLFF results for 3.c:
# {'bias': 0.0,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([-0., -0.])}
#
# SLFF results for 3.c with no bias:
# {'bias': None,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([0., 0.])}
#
# SLFF results for 3.c with learning rate 0.1:
# {'bias': 0.0,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([-0., -0.])}
#
# SLFF results for 3.c with learning rate 0.5:
# {'bias': 0.0,
#  'epoch': 9999,
#  'outputs': array([0.5, 0.5, 0.5, 0.5]),
#  'tss': 1.0,
#  'weights': array([-0., -0.])}
# ---------------------------------------------

# %% [markdown]
# # Questions
#
# 1. What effect does **the activation function** have on the ability of the network to learn the patterns?
#
# As it is shown using Single-Layer Feed-Forward, and a **threshold** activation function the **AND** and **OR** patterns learned very well with a tss equal to 0.
# Using a **linear** activation function after 10000 epochs although tss is close to 0 but not as good as threshold activation function.
# An by **sigmoid** activation function tss is really close to 0.
# As it was supposed to happen, non of these activation functions could learn **XOR**, because this pattern needs at least one hidden layer to be learned.
#
# 2. What is the effect of removing the **Bias** term?
#
# Removing bias had a great deffect on performances and except the OR pattern using threshold activation function, in almost all others removing bias distorted the learning process.
#
# 3. What is the effect of changing the learning rate (**Lrate**)? Does changing the learning rate make it possible to learn some patterns that could not otherwise be learned? Does changing the learning rate make it impossible to learn some patterns that could otherwise be learned?
#
# Here I used 3 different learning rates: 0.05, 0.1, and 0.5. By increasing learning rate for threshold activation function the number of epochs or the time for reaching 0 tss decreased. But had no effect on almost all other learning methods. For some of them a large learning rate caused instability and making some values having None-defined values.
#
#
# Hand in a listing of each of the programs used in the assignment. Include in your report, the value of the time variable, t, when the TSS reached zero; if the TSS never reached zero, indicate why the patterns could not be learned. Your report should be brief but different aspects of each case be explained clearly and completely.
#
# The time variable is indicated by epochs number if the loop is reaching tss of 0 sooner than reaching the defined number of epochs. So, for example for threshold activation function, it took 1-20 epochs to learn AND and OR patterns and reaching a 0 tss. However, since other methods did not reach zero tss, they got closser to zero by increasing epoch number or time spent.
